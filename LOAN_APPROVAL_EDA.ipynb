# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn  as sns

# %% [markdown]
# ## Load Dataset

# %%
df=pd.read_csv(r"C:\Users\rohit\Downloads\loan_data.csv")

# %% [markdown]
# ## View First Rows

# %%
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# ...

# %% [markdown]
# ## Missing Values Count

# %%
df.isna().sum()
# Out:
# person_age                        0
# person_gender                     0
# person_education                  0
# person_income                     0
# person_emp_exp                    0
# person_home_ownership             0
# loan_amnt                         0
# loan_intent                       0
# loan_int_rate                     0
# loan_percent_income               0
# cb_person_cred_hist_length        0
# credit_score                      0
# previous_loan_defaults_on_file    0
# loan_status                       0
# dtype: int64

# %% [markdown]
# ## Data Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      45000 non-null  float64
#  1   person_gender                   45000 non-null  object
#  2   person_education                45000 non-null  object
#  3   person_income                   45000 non-null  float64
#  4   person_emp_exp                  45000 non-null  int64
#  5   person_home_ownership           45000 non-null  object
#  6   loan_amnt                       45000 non-null  float64
#  7   loan_intent                     45000 non-null  object
#  8   loan_int_rate                   45000 non-null  float64
#  9   loan_percent_income             45000 non-null  float64
#  10  cb_person_cred_hist_length      45000 non-null  float64
#  11  credit_score                    45000 non-null  int64
# ...

# %% [markdown]
# ## Statistical Summary

# %%
df.describe()
# Out:
#          person_age  person_income  person_emp_exp     loan_amnt  \
# count  45000.000000   4.500000e+04    45000.000000  45000.000000
# mean      27.764178   8.031905e+04        5.410333   9583.157556
# std        6.045108   8.042250e+04        6.063532   6314.886691
# min       20.000000   8.000000e+03        0.000000    500.000000
# 25%       24.000000   4.720400e+04        1.000000   5000.000000
# 50%       26.000000   6.704800e+04        4.000000   8000.000000
# 75%       30.000000   9.578925e+04        8.000000  12237.250000
# max      144.000000   7.200766e+06      125.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   45000.000000         45000.000000                45000.000000
# mean       11.006606             0.139725                    5.867489
# std         2.978808             0.087212                    3.879702
# min         5.420000             0.000000                    2.000000
# ...

# %% [markdown]
# ## Missing Values Count (Duplicate)

# %%
df.isna().sum()
# Out:
# person_age                        0
# person_gender                     0
# person_education                  0
# person_income                     0
# person_emp_exp                    0
# person_home_ownership             0
# loan_amnt                         0
# loan_intent                       0
# loan_int_rate                     0
# loan_percent_income               0
# cb_person_cred_hist_length        0
# credit_score                      0
# previous_loan_defaults_on_file    0
# loan_status                       0
# dtype: int64

# %% [markdown]
# ## Select Numerical Columns

# %%
num_cols=df.select_dtypes(exclude='object').columns
cat_cols=df.select_dtypes(include='object').columns
num_cols,cat_cols
# Out:
# (Index(['person_age', 'person_income', 'person_emp_exp', 'loan_amnt',
#         'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length',
#         'credit_score', 'loan_status'],
#        dtype='object'),
#  Index(['person_gender', 'person_education', 'person_home_ownership',
#         'loan_intent', 'previous_loan_defaults_on_file'],
#        dtype='object'))

# %% [markdown]
# ## Distribution: Person Income

# %%
sns.histplot(df['person_income'])
# Out:
# <Axes: xlabel='person_income', ylabel='Count'>

# %% [markdown]
# ## Boxplot: Person Income

# %%
sns.boxplot(df['person_income'])
plt.title("OUTLIERS OF INCOME")
# Out:
# Text(0.5, 1.0, 'OUTLIERS OF INCOME')

# %% [markdown]
# ## Boxplot: Loan Amount

# %%
sns.boxplot(df['loan_amnt'])
plt.title("OUTLIERS OF LOAN AMOUNT")
# Out:
# Text(0.5, 1.0, 'OUTLIERS OF LOAN AMOUNT')

# %% [markdown]
# ## Distribution: Credit Score

# %%
sns.histplot(df['credit_score'])
plt.title("DISTRIBUTION OF CREDIT SCORE")
# Out:
# Text(0.5, 1.0, 'DISTRIBUTION OF CREDIT SCORE')

# %% [markdown]
# ## Countplot: Education

# %%
sns.countplot(df['person_education'])
# Out:
# <Axes: xlabel='count', ylabel='person_education'>

# %% [markdown]
# ## Boxplot: Income vs Loan Status

# %%
sns.boxplot(x=df['loan_status'],y=df['person_income'],data=df)
# Out:
# <Axes: xlabel='loan_status', ylabel='person_income'>

# %% [markdown]
# ## KDE: Credit Score by Loan Status

# %%
sns.kdeplot(x=df['credit_score'],data=df,hue=df['loan_status'])
# Out:
# <Axes: xlabel='credit_score', ylabel='Density'>

# %% [markdown]
# ## Boxplot: Loan Amount vs Loan Status

# %%
sns.boxplot(x=df['loan_status'],y=df['loan_amnt'])
# Out:
# <Axes: xlabel='loan_status', ylabel='loan_amnt'>

# %% [markdown]
# ## Correlation Matrix

# %%
cor=df[num_cols].corr()

# %% [markdown]
# ## Heatmap

# %%
sns.heatmap(cor,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Pairplot

# %%
sns.pairplot(df[['person_income', 'loan_amnt', 'credit_score', 'loan_status']],hue='loan_status')

# %% [markdown]
# ## Empty Cell
